# %% [markdown]
# # Debug: L0 Calibration
#
# Interactive notebook for debugging pypff conversion and calibration.

# %%
from pathlib import Path
import xarray as xr
import numpy as np

# %% [markdown]
# ## Inspect L0

# %%
l0_path = "../../results_tutorial/L0/obs_TEST.pffd.dp_img16.bpp_2.module_1.debug_TRUNCATED.zarr"
ds = xr.open_zarr(l0_path, consolidated=False)
display(ds)
