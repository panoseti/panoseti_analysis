# %% [markdown]
# # Debug: ML Inference
#
# Deep dive into PyTorch model logits and thresholds.

# %%
import torch
import numpy as np
from panoseti_analysis.io.models import load_classifier

# %% [markdown]
# ## Model Inspection

# %%
model, bundle = load_classifier("../../assets/models/cloud_detector_v1.pt")
model.eval()

# Create a dummy batch of features (N, 2, 32, 32)
dummy_input = torch.randn(4, 2, 32, 32)
with torch.no_grad():
    logits = model(dummy_input)
    probs = torch.nn.functional.softmax(logits, dim=1)
    
print("Logits:\n", logits)
print("Probs:\n", probs)
