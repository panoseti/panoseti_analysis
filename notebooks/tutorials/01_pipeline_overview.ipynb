# %% [markdown]
# # Tutorial 1: Pipeline Overview
#
# This notebook introduces the PANOSETI data-reduction pipeline. The pipeline is orchestrated via **Nextflow** and processes data in "levels" (L0, L1, L2).

# %% [markdown]
# ## Running the pipeline locally
#
# We can invoke the pipeline using `nextflow run .` in the terminal. In this notebook, we can just run it using bash commands.

# %%
# !pwd
# Out:
# /home/nico/panoseti_analysis/notebooks/tutorials

# %%
# !nextflow run ../../main.nf -profile test,laptop --steps ingest,ml --outdir results_tutorial -resume
# Out:
#  N E X T F L O W   ~  version 26.04.3
#
# WARN: It appears you have never run this project before -- Option `-resume` is ignored
# Downloading plugin nf-schema@2.5.1
# Launching `../../main.nf` [ridiculous_crick] revision: 3e3041c579
#
# WARN: It appears you have never run this project before -- Option `-resume` is ignored
# Input/output options
#   input_obs_dir      : /home/nico/panoseti_analysis/tests/data/obs_TEST.pffd
#   outdir             : results_tutorial
#
# Generic options
#   trace_report_suffix: 2026-06-01_15-41-14
#
# PANOSETI ingest options
#   steps              : ingest,ml
#   ph_stride          : 50
#   img_stride         : 50
#
# Core Nextflow options
#   runName            : ridiculous_crick
#   launchDir          : /home/nico/panoseti_analysis/notebooks/tutorials
#   workDir            : /home/nico/panoseti_analysis/notebooks/tutorials/work
#   projectDir         : /home/nico/panoseti_analysis
#   userName           : nico
#   profile            : test,laptop
#   configFiles        : /home/nico/panoseti_analysis/nextflow.config
#
# !! Only displaying parameters that differ from the pipeline defaults !!
# ------------------------------------------------------
# WARN: The following invalid input values have been detected:
#
# * --config_profile_description: Minimal bundled obs_TEST.pffd to check pipeline function
# * --ray_launcher: slurm
# * --config_profile_name: Test profile
#
#
# [-        ] PAN…NALYSIS:INGEST:PFF_TO_ZARR -
# [-        ] PAN…S:ANALYSIS:INGEST:BUILD_HK -
# [-        ] PAN…ALYSIS:INGEST:CALIBRATE_PH -
# [-        ] PAN…LYSIS:INGEST:CALIBRATE_IMG -
# [-        ] PAN…S:INGEST:BUILD_MANIFEST_L0 -
#
# [-        ] PAN…NALYSIS:INGEST:PFF_TO_ZARR -
# [-        ] PAN…S:ANALYSIS:INGEST:BUILD_HK -
# [-        ] PAN…ALYSIS:INGEST:CALIBRATE_PH -
# [-        ] PAN…LYSIS:INGEST:CALIBRATE_IMG -
# [-        ] PAN…S:INGEST:BUILD_MANIFEST_L0 -
# [-        ] PAN…S:INGEST:BUILD_MANIFEST_L1 -
# [-        ] PAN…Y_CLOUD:CLASSIFY_CLOUD_CPU -
# [-        ] PAN…LYSIS:ML:BUILD_MANIFEST_L2 -
#
# executor >  local (2)
# [3d/ae6ba8] PAN…EST:PFF_TO_ZARR (obs_TEST) | 0 of 1
# [2c/39eb35] PAN…INGEST:BUILD_HK (obs_TEST) | 0 of 1
# [-        ] PAN…ALYSIS:INGEST:CALIBRATE_PH -
# [-        ] PAN…LYSIS:INGEST:CALIBRATE_IMG -
# [-        ] PAN…S:INGEST:BUILD_MANIFEST_L0 -
# [-        ] PAN…S:INGEST:BUILD_MANIFEST_L1 -
# [-        ] PAN…Y_CLOUD:CLASSIFY_CLOUD_CPU -
# [-        ] PAN…LYSIS:ML:BUILD_MANIFEST_L2 -
#
# executor >  local (2)
# [3d/ae6ba8] PAN…EST:PFF_TO_ZARR (obs_TEST) | 0 of 1
# [2c/39eb35] PAN…INGEST:BUILD_HK (obs_TEST) | 0 of 1
# [-        ] PAN…ALYSIS:INGEST:CALIBRATE_PH -
# [-        ] PAN…LYSIS:INGEST:CALIBRATE_IMG -
# [-        ] PAN…S:INGEST:BUILD_MANIFEST_L0 -
# [-        ] PAN…S:INGEST:BUILD_MANIFEST_L1 -
# [-        ] PAN…Y_CLOUD:CLASSIFY_CLOUD_CPU -
# [-        ] PAN…LYSIS:ML:BUILD_MANIFEST_L2 -
#
# executor >  local (2)
# [3d/ae6ba8] PAN…EST:PFF_TO_ZARR (obs_TEST) | 0 of 1
# [2c/39eb35] PAN…INGEST:BUILD_HK (obs_TEST) | 1 of 1 ✔
# [-        ] PAN…ALYSIS:INGEST:CALIBRATE_PH -
# [-        ] PAN…LYSIS:INGEST:CALIBRATE_IMG -
# [-        ] PAN…S:INGEST:BUILD_MANIFEST_L0 -
# [-        ] PAN…S:INGEST:BUILD_MANIFEST_L1 -
# [-        ] PAN…Y_CLOUD:CLASSIFY_CLOUD_CPU -
# [-        ] PAN…LYSIS:ML:BUILD_MANIFEST_L2 -
#
# executor >  local (2)
# [3d/ae6ba8] PAN…EST:PFF_TO_ZARR (obs_TEST) | 1 of 1 ✔
# [2c/39eb35] PAN…INGEST:BUILD_HK (obs_TEST) | 1 of 1 ✔
# [-        ] PAN…ALYSIS:INGEST:CALIBRATE_PH -
# [-        ] PAN…LYSIS:INGEST:CALIBRATE_IMG -
# [-        ] PAN…S:INGEST:BUILD_MANIFEST_L0 -
# [-        ] PAN…S:INGEST:BUILD_MANIFEST_L1 -
# [-        ] PAN…Y_CLOUD:CLASSIFY_CLOUD_CPU -
# [-        ] PAN…LYSIS:ML:BUILD_MANIFEST_L2 -
#
# executor >  local (5)
# [3d/ae6ba8] PAN…EST:PFF_TO_ZARR (obs_TEST) | 1 of 1 ✔
# [2c/39eb35] PAN…INGEST:BUILD_HK (obs_TEST) | 1 of 1 ✔
# [3a/c57478] PAN…IBRATE_PH (ph256.module_1) | 0 of 1
# [f3/1269ee] PAN…BRATE_IMG (img16.module_1) | 0 of 1
# [5e/dd2229] PAN…_MANIFEST_L0 (obs_TEST:L0) | 0 of 1
# [-        ] PAN…S:INGEST:BUILD_MANIFEST_L1 -
# [-        ] PAN…Y_CLOUD:CLASSIFY_CLOUD_CPU -
# [-        ] PAN…LYSIS:ML:BUILD_MANIFEST_L2 -
#
# executor >  local (5)
# [3d/ae6ba8] PAN…EST:PFF_TO_ZARR (obs_TEST) | 1 of 1 ✔
# [2c/39eb35] PAN…INGEST:BUILD_HK (obs_TEST) | 1 of 1 ✔
# [3a/c57478] PAN…IBRATE_PH (ph256.module_1) | 0 of 1
# [f3/1269ee] PAN…BRATE_IMG (img16.module_1) | 0 of 1
# [5e/dd2229] PAN…_MANIFEST_L0 (obs_TEST:L0) | 1 of 1 ✔
# [-        ] PAN…S:INGEST:BUILD_MANIFEST_L1 -
# [-        ] PAN…Y_CLOUD:CLASSIFY_CLOUD_CPU -
# [-        ] PAN…LYSIS:ML:BUILD_MANIFEST_L2 -
#
# executor >  local (5)
# [3d/ae6ba8] PAN…EST:PFF_TO_ZARR (obs_TEST) | 1 of 1 ✔
# [2c/39eb35] PAN…INGEST:BUILD_HK (obs_TEST) | 1 of 1 ✔
# [3a/c57478] PAN…IBRATE_PH (ph256.module_1) | 1 of 1 ✔
# [f3/1269ee] PAN…BRATE_IMG (img16.module_1) | 0 of 1
# [5e/dd2229] PAN…_MANIFEST_L0 (obs_TEST:L0) | 1 of 1 ✔
# [-        ] PAN…S:INGEST:BUILD_MANIFEST_L1 -
# [-        ] PAN…Y_CLOUD:CLASSIFY_CLOUD_CPU -
# [-        ] PAN…LYSIS:ML:BUILD_MANIFEST_L2 -
#
# executor >  local (5)
# [3d/ae6ba8] PAN…EST:PFF_TO_ZARR (obs_TEST) | 1 of 1 ✔
# [2c/39eb35] PAN…INGEST:BUILD_HK (obs_TEST) | 1 of 1 ✔
# [3a/c57478] PAN…IBRATE_PH (ph256.module_1) | 1 of 1 ✔
# [f3/1269ee] PAN…BRATE_IMG (img16.module_1) | 1 of 1 ✔
# [5e/dd2229] PAN…_MANIFEST_L0 (obs_TEST:L0) | 1 of 1 ✔
# [-        ] PAN…S:INGEST:BUILD_MANIFEST_L1 -
# [-        ] PAN…Y_CLOUD:CLASSIFY_CLOUD_CPU -
# [-        ] PAN…LYSIS:ML:BUILD_MANIFEST_L2 -
#
# executor >  local (7)
# [3d/ae6ba8] PAN…EST:PFF_TO_ZARR (obs_TEST) | 1 of 1 ✔
# [2c/39eb35] PAN…INGEST:BUILD_HK (obs_TEST) | 1 of 1 ✔
# [3a/c57478] PAN…IBRATE_PH (ph256.module_1) | 1 of 1 ✔
# [f3/1269ee] PAN…BRATE_IMG (img16.module_1) | 1 of 1 ✔
# [5e/dd2229] PAN…_MANIFEST_L0 (obs_TEST:L0) | 1 of 1 ✔
# [09/4a9f9c] PAN…_MANIFEST_L1 (obs_TEST:L1) | 0 of 1
# [9f/578203] PAN…OUD:CLASSIFY_CLOUD_CPU (1) | 0 of 1
# [-        ] PAN…LYSIS:ML:BUILD_MANIFEST_L2 -
#
# executor >  local (7)
# [3d/ae6ba8] PAN…EST:PFF_TO_ZARR (obs_TEST) | 1 of 1 ✔
# [2c/39eb35] PAN…INGEST:BUILD_HK (obs_TEST) | 1 of 1 ✔
# [3a/c57478] PAN…IBRATE_PH (ph256.module_1) | 1 of 1 ✔
# [f3/1269ee] PAN…BRATE_IMG (img16.module_1) | 1 of 1 ✔
# [5e/dd2229] PAN…_MANIFEST_L0 (obs_TEST:L0) | 1 of 1 ✔
# [09/4a9f9c] PAN…_MANIFEST_L1 (obs_TEST:L1) | 1 of 1 ✔
# [9f/578203] PAN…OUD:CLASSIFY_CLOUD_CPU (1) | 0 of 1
# [-        ] PAN…LYSIS:ML:BUILD_MANIFEST_L2 -
#
# executor >  local (8)
# [3d/ae6ba8] PAN…EST:PFF_TO_ZARR (obs_TEST) | 1 of 1 ✔
# [2c/39eb35] PAN…INGEST:BUILD_HK (obs_TEST) | 1 of 1 ✔
# [3a/c57478] PAN…IBRATE_PH (ph256.module_1) | 1 of 1 ✔
# [f3/1269ee] PAN…BRATE_IMG (img16.module_1) | 1 of 1 ✔
# [5e/dd2229] PAN…_MANIFEST_L0 (obs_TEST:L0) | 1 of 1 ✔
# [09/4a9f9c] PAN…_MANIFEST_L1 (obs_TEST:L1) | 1 of 1 ✔
# [9f/578203] PAN…OUD:CLASSIFY_CLOUD_CPU (1) | 1 of 1 ✔
# [b9/f43951] PAN…_MANIFEST_L2 (obs_TEST:L2) | 0 of 1
#
# executor >  local (8)
# [3d/ae6ba8] PAN…EST:PFF_TO_ZARR (obs_TEST) | 1 of 1 ✔
# [2c/39eb35] PAN…INGEST:BUILD_HK (obs_TEST) | 1 of 1 ✔
# [3a/c57478] PAN…IBRATE_PH (ph256.module_1) | 1 of 1 ✔
# [f3/1269ee] PAN…BRATE_IMG (img16.module_1) | 1 of 1 ✔
# [5e/dd2229] PAN…_MANIFEST_L0 (obs_TEST:L0) | 1 of 1 ✔
# [09/4a9f9c] PAN…_MANIFEST_L1 (obs_TEST:L1) | 1 of 1 ✔
# [9f/578203] PAN…OUD:CLASSIFY_CLOUD_CPU (1) | 1 of 1 ✔
# [b9/f43951] PAN…_MANIFEST_L2 (obs_TEST:L2) | 0 of 1
#
# executor >  local (8)
# [3d/ae6ba8] PAN…EST:PFF_TO_ZARR (obs_TEST) | 1 of 1 ✔
# [2c/39eb35] PAN…INGEST:BUILD_HK (obs_TEST) | 1 of 1 ✔
# [3a/c57478] PAN…IBRATE_PH (ph256.module_1) | 1 of 1 ✔
# [f3/1269ee] PAN…BRATE_IMG (img16.module_1) | 1 of 1 ✔
# [5e/dd2229] PAN…_MANIFEST_L0 (obs_TEST:L0) | 1 of 1 ✔
# [09/4a9f9c] PAN…_MANIFEST_L1 (obs_TEST:L1) | 1 of 1 ✔
# [9f/578203] PAN…OUD:CLASSIFY_CLOUD_CPU (1) | 1 of 1 ✔
# [b9/f43951] PAN…_MANIFEST_L2 (obs_TEST:L2) | 1 of 1 ✔
#
# executor >  local (8)
# [3d/ae6ba8] PAN…EST:PFF_TO_ZARR (obs_TEST) | 1 of 1 ✔
# [2c/39eb35] PAN…INGEST:BUILD_HK (obs_TEST) | 1 of 1 ✔
# [3a/c57478] PAN…IBRATE_PH (ph256.module_1) | 1 of 1 ✔
# [f3/1269ee] PAN…BRATE_IMG (img16.module_1) | 1 of 1 ✔
# [5e/dd2229] PAN…_MANIFEST_L0 (obs_TEST:L0) | 1 of 1 ✔
# [09/4a9f9c] PAN…_MANIFEST_L1 (obs_TEST:L1) | 1 of 1 ✔
# [9f/578203] PAN…OUD:CLASSIFY_CLOUD_CPU (1) | 1 of 1 ✔
# [b9/f43951] PAN…_MANIFEST_L2 (obs_TEST:L2) | 1 of 1 ✔
# -[panoseti/analysis] Pipeline completed successfully-
#
# Outputs:
#
#   /home/nico/panoseti_analysis/notebooks/tutorials/results_tutorial
#
#   l0_stores:
#     - L0/obs_TEST.pffd.dp_img16.bpp_2.module_1.debug_TRUNCATED.zarr
#     - L0/obs_TEST.pffd.dp_ph256.bpp_2.module_1.debug_TRUNCATED.zarr
#
#   l1_stores:
#     - L1/obs_TEST.dp_ph256.module_1.L1.zarr
#     - L1/obs_TEST.dp_img16.module_1.L1.zarr
#
#   hk_stores:
#
#   l0_manifest:
#     - L0/manifest.json
#
#   l1_manifest:
#     - L1/manifest.json
#
#   l2_stores:
#     - L2/obs_TEST.cloud.module_1.zarr
#
#   l2_manifest:
#     - L2/manifest.json
#
#   l2_quicklooks:
#     - L2_quicklooks/obs_TEST.cloud.module_1.quicklook.png

# %% [markdown]
# ## Exploring the outputs
#
# The pipeline output directory contains `L0`, `L1`, `L2`, and `L2_quicklooks` products.

# %%
# !ls -la results_tutorial/
# Out:
# total 28
# drwxrwxr-x 7 nico nico 4096 Jun  1 15:41 .
# drwxrwxr-x 7 nico nico 4096 Jun  1 15:41 ..
# drwxrwxr-x 4 nico nico 4096 Jun  1 15:41 L0
# drwxrwxr-x 4 nico nico 4096 Jun  1 15:41 L1
# drwxrwxr-x 3 nico nico 4096 Jun  1 15:41 L2
# drwxrwxr-x 3 nico nico 4096 Jun  1 15:41 L2_quicklooks
# drwxrwxr-x 2 nico nico 4096 Jun  1 15:41 pipeline_info
